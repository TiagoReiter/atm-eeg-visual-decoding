# %%
import torch
import numpy as np
import pandas as pd

file_path_eegnet = r"D:\Universität\Master\4. Semester\Forschungspraxis\fp_python\Data\Raw\EEG ImageNet\EEG-ImageNet_1.pth"
file_path_things = r"D:\Universität\Master\4. Semester\Forschungspraxis\fp_python\Data\Raw\Things EEG\sub-01\ses-01\raw_eeg_training.npy"

checkpoint_eegnet = torch.load(file_path_eegnet, map_location=torch.device('cpu'), weights_only=False)
npy_data = np.load(file_path_things, allow_pickle=True)
print("EEGNet keys ", checkpoint_eegnet.keys())

print("Type of data:", type(npy_data))
print("Shape of data:", npy_data.shape)
print("Data type of elements:", npy_data.dtype)


df = pd.DataFrame(npy_data)
df.to_csv('THINGS_EEG.csv', index=False)
df.to_csv('THINGS_EEG.txt', sep='\t', index=False)
# If it's a structured array or multi-dimensional array, print a sample
# Out:
# EEGNet keys  dict_keys(['dataset', 'labels', 'images'])
# Type of data: <class 'numpy.ndarray'>
# Shape of data: ()
# Data type of elements: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 17
#      13 print("Shape of data:", npy_data.shape)
#      14 print("Data type of elements:", npy_data.dtype)
# ---> 17 df = pd.DataFrame(npy_data)
#      18 df.to_csv('THINGS_EEG.csv', index=False)
#      19 df.to_csv('THINGS_EEG.txt', sep='\t', index=False)
#
# File c:\Users\User\anaconda3\envs\BCI\lib\site-packages\pandas\core\frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)
#     824             copy=_copy,
#     825         )
#     826     else:
# ...
